# %% [markdown]
# <font size="5">Статистический анализ данных испаноговорящих испытуемых (Statistical analysis of spanish speaking subjects inner speech) &#x1F60E; </font>

# %% [markdown]
# <font size="2">На момент написания используются данные 10 испытуемых предварительно разделеннных на эпохи. Посчитаем спектры, выделим под-диапазон 60-65 в гамма диапазоне, посчитаем статистики между фон/слово и слово/cлово и посмотрим пересечения между испытуемыми.
# (Ten subjects data divided to 1 sec epochs was used in this research. We will calculate PSD in 60-65 Hz band, t-test and anova comapring word pronaunce state and rest state) </font> 	&#x1F600;

# %%
import os 
import numpy as np
from numpy.linalg import eig
import mne
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sys
from itertools import combinations

from scipy.stats import ttest_ind, f_oneway
from scipy import signal
from scipy import stats

from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.pipeline import Pipeline
from sklearn.utils import shuffle
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.decomposition import PCA, FastICA, KernelPCA
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE, RandomOverSampler, SVMSMOTE, ADASYN, BorderlineSMOTE, KMeansSMOTE
from imblearn.ensemble import EasyEnsembleClassifier
import smote_variants
from xgboost import XGBRFClassifier

from mne.decoding import CSP

# %%
def getList(dict):
    list = []
    for key in dict.keys():
        list.append(key)
    return list

# %%
#подгрузка эпох. Лучше грузить без прелоуда, чтобы не грузить оперативку
#loading epoch without preload to avoid extra ram usage
mainPath = r'/home/dataFolder/DataPrior/Spanish/epo'
epoData = []
loadR = [1,10]
for i in range(loadR[0],loadR[1]):
    epoData.append(mne.read_epochs(mainPath + '/' + 'sub-{}'.format(i) + '/' + 'sub-{}-epo.fif'.format(i), preload = False, verbose = 0))

# %%
#посчитаем спектры в суббэнде гаммы
#calc PSD in gamma band's subband
#поправка: посчитаем всё, разделим по бэндам
psd = [epochmne.compute_psd(method='multitaper',fmin=4, fmax=65,n_jobs = -1)[[ 'BACK2',
                                                                                'DOWN2',
                                                                                'FORWARD2',
                                                                                'LEFT2',
                                                                                'NEXT2',
                                                                                'RIGHT2',
                                                                                'UP2','GO']] for epochmne in epoData]
# Out:
# Loading data for 1611 events and 500 original time points ...
#     Using multitaper spectrum estimation with 7 DPSS windows
# Loading data for 2188 events and 500 original time points ...
#     Using multitaper spectrum estimation with 7 DPSS windows
# Loading data for 1081 events and 500 original time points ...
#     Using multitaper spectrum estimation with 7 DPSS windows
# Loading data for 1148 events and 500 original time points ...
#     Using multitaper spectrum estimation with 7 DPSS windows
# Loading data for 1637 events and 500 original time points ...
#     Using multitaper spectrum estimation with 7 DPSS windows
# Loading data for 1532 events and 500 original time points ...
#     Using multitaper spectrum estimation with 7 DPSS windows
# Loading data for 1600 events and 500 original time points ...
#     Using multitaper spectrum estimation with 7 DPSS windows
# Loading data for 1405 events and 500 original time points ...
#     Using multitaper spectrum estimation with 7 DPSS windows
# Loading data for 1247 events and 500 original time points ...
#     Using multitaper spectrum estimation with 7 DPSS windows

# %%
#divide by subbands 
bands = [(4,8),(8,13),(13,19),(19,30),(30,45),(60,65)]
bandName = ['Theta','Alpha','Beta_1','Beta_2','Gamma_1','Gamma_2']
#no need in this  actually will be done later?
spec = {}
for indx, sub in enumerate(psd):
    curSpec = {}
    for band, name in zip(bands, bandName):
        band_data = sub.get_data()[:,:,band[0]:band[1]]
        mean_band = np.mean(band_data, axis = 2)
        curSpec[name] = mean_band
    spec[indx] = curSpec

# %%
#усредним значения по диапазону, посчитем t статистику по всем каналам
#mean the spectrum and calc t test
resTest = {}
pThres = 0.0001
uniWords = True
for indx, sub in enumerate(psd):
    goSt = np.mean(sub['GO'].get_data(), axis = 2)
    stateDict = {}
    #wether to unite all words to one class or not (it will differ the output dictionary format)
    if uniWords == True:
        #are full spectres calculated?
        stateDict = {}
        bandRes = {}
        for band, b in zip(bandName, bands):
            #we divided spectrum to subbands previously, but the way this block was implemented moved to reinventing the wheel
            wordSt = np.mean(sub[[w for w in getList(sub.event_id) if w != 'GO']].get_data()[:,:,b[0]:b[1]], axis = 2)
            chRes = []
            for ind, ch in enumerate(sub.ch_names):
                t, p = f_oneway(wordSt[:,ind], goSt[:,ind])
                if p < pThres:
                    chRes.append([ch,p])
            bandRes[band] = chRes
        stateDict['WORD'] = bandRes
        resTest[indx] = stateDict
    else:
        for state in getList(sub.event_id):
            curSt = np.mean(sub[state].get_data(), axis = 2)
            chRes = []
            if state == 'GO':
                continue
            for ind, ch in enumerate(sub.ch_names):
                t, p = ttest_ind(curSt[:,ind], goSt[:,ind], equal_var=False)
                #t, p = f_oneway(curSt[:,ind], goSt[:,ind])
                
                stMean = np.mean(curSt[:,ind])
                goMean = np.mean(goSt[:,ind])
                
                if p < pThres:
                    #if stMean >  goMean:
                    chRes.append([ch,p])
                        
            stateDict[state] = chRes
        resTest[indx] = stateDict

# %%
#сгруппируем по словам, а не людям
#group by words
byWord = {}
byBand = {}
for band  in bandName:
    for key in resTest[0].keys():
        cur = []
        for sesKey in resTest.keys():
            cur = cur + [i[0] for i in resTest[sesKey][key][band]]
        byBand[band] = cur
    byWord[key] = byBand

# %%
#посмомтрим насколько часто встречается канал
#let's see how common the channel is
frequency = {}
for keys in byWord.keys():
    bandFreq = {}
    for band in bandName:
        test_list = byWord[keys][band]
        unique_elements = set(test_list)
        bandFreq[band] = {item: test_list.count(item) for item in unique_elements}
    frequency[key] = bandFreq

# %%
#построим на топокарте 
#let's plot a commonnes distribution on topomap
freqData = {item: {band: [frequency[item][band][ch] if ch in getList(frequency[item][band]) else 0 for ch in epoData[0].ch_names] for band in bandName} for item in frequency.keys()}
_, pos, _, _, _, _, _ = mne.viz.topomap._prepare_topomap_plot(epoData[0].info, 'eeg',sphere = 'auto')
if freqData.keys() > freqData[list(freqData.keys())[0]].keys():
    cols = len(freqData.keys())
    rows = len(freqData[list(freqData.keys())[0]].keys())
else:
    cols = len(freqData[list(freqData.keys())[0]].keys())
    rows = len(freqData.keys())
    
# if len(frequency.keys()) < 5:
#     figsize = (5,3)
# else:
#     figsize = (18,10)
    
fig, axes = plt.subplots(rows, cols, figsize = (18,10), squeeze=False)
for idx_1, key_1 in enumerate(freqData.keys()):
    for idx_2, key_2 in enumerate(freqData[list(freqData.keys())[0]].keys()):
        axes[idx_1,idx_2].set_title(key_2)
        mne.viz.plot_topomap(freqData[key_1][key_2], pos, names = epoData[0].ch_names, axes = axes[idx_1,idx_2], show = False)      
plt.show()
#fig.savefig('st<go.png')

# %%
#ранжируем список частот появления каналов, сохранив индексы (формат: (индекс, значение)). Индекс нужен, чтобы знать название канала
#sort the commoness list saving indices
sortFreq = {word: sorted(enumerate(freqData[word]), key=lambda i: i[1]) for word in freqData.keys()}
#теперь необходимо найти первый квартиль? или первые десять процентов наибольших значений?
#is it reasonable to look only for the most common channels? let's say the first quartile? or may be first 10%?
firstQ = {}
for word in sortFreq:
    m = 9 * (len(sortFreq[word]) + 1) // 10
    firstQ[word] = sortFreq[word][m:]
####найдем пересечения для значимых каналов####
#уникальные каналы
#find unique channels
uniCh = np.concatenate([[j[0] for j in firstQ[word]] for word in firstQ.keys()])
#пройдёмся по этим каналам и словам
#iterate through channels and words, reform data structure
chFreq = {}
for ch in uniCh:
    chFreq[epoData[0].ch_names[ch]] = []
    for word in firstQ.keys():
        for el in firstQ[word]:
            if ch == el[0]:
                chFreq[epoData[0].ch_names[ch]].append(word)

# %%
#представим полученные результаты в виде матрицы
#form the result as matrix hoping to group words by channels
matchMat = np.zeros((7, len(epoData[0].ch_names)))
for j_ind, ch in enumerate(epoData[0].ch_names):
    if ch in chFreq.keys():
        for i_ind, word in enumerate(firstQ.keys()):
            if word in chFreq[ch]:
                matchMat[i_ind,j_ind] = 1
            else:
                continue
    else:
        continue

# %%
#построим
#plot the result
fig1, ax1 = plt.subplots(figsize = (15,5))
im = ax1.imshow(matchMat, cmap="YlGn")

ax1.set_xticks(np.arange(len(epoData[0].ch_names)), epoData[0].ch_names)
ax1.set_yticks(np.arange(len(firstQ.keys())), labels = firstQ.keys())

for i in range(len(epoData[0].ch_names)):
    for j in range(len(firstQ.keys())):
        if matchMat[j, i] != 0:
            text = ax1.text(i, j, matchMat[j, i],
                           ha="center", va="center", color="w")

# %% [markdown]
# <font size="2.5">**Impact of Class Imbalance on SVM with RBF Kernel**</font>
#
# --Bias Towards Majority Class: In imbalanced datasets, SVM tends to classify most instances as belonging to the majority class. This is particularly problematic when the minority class is of   significant interest, as the classifier may ignore important patterns associated with the minority class, leading to poor recall and overall performance.
#
# --Parameter Sensitivity: The performance of SVM with RBF kernel is sensitive to the parameters  C (the penalty for misclassification) and γ (which defines the influence of a single training example). When dealing with imbalanced data, careful tuning of these parameters is crucial. A high C value can lead to overfitting, especially when the minority class is underrepresented, while a low  C may result in underfitting.

# %%
#посмотрим, как после своеобразного "channel selection" будет работать бинарная классификация гамма диапаозона в ГО/слово в loso кросс-валидации
#let's see how our "channel selection" results works  on binary classifiaction task with LOSO estimation
saveTrain = True
overSampTest = False
saved_x = []
saved_y = []
saved_pred = []
accuracies = []
overSamp = True
for w_ind, word in enumerate(firstQ.keys()):
    acc_cur = []
    for indx, sub in enumerate(psd):
        #подготовим пайплайн со стандартизацией и смешиванием данных
        #prepare pipeline with standartization and shuffling with random forest as an output unit
        pipeline = Pipeline([
            #('scaler', StandardScaler()), 
            ('classifier', RandomForestClassifier(n_estimators = 700,random_state=42, n_jobs = -1))
            #('pca', PCA(n_components = 3)),
            #('svm', SVC(kernel='rbf', gamma='scale'))
        ])
        #########################################################################################
        #значимые каналы под слово
        #significant channels for current word
        ch_ind = np.squeeze(np.argwhere(matchMat[w_ind,:] == 1))
        #тренировочный сет, данные всех испутемых кроме текущего
        #train set, concatenate data of all subjects except current one
        train_x = np.concatenate([np.mean(x[['GO', word]].get_data(), axis = 2)[:,ch_ind] for i,x in enumerate(psd) if i!=indx])
        train_y = np.concatenate([y[['GO', word]].events[:,2] for i,y in enumerate(psd) if i!=indx])
        #если надо уравнять классы
        #if oversampling is needed
        if overSamp == True:
            over_sampler = smote_variants.Supervised_SMOTE()
            train_x, train_y = over_sampler.sample(train_x, train_y)
        if saveTrain == True:
            saved_x.append(train_x)
            saved_y.append(train_y)
        #тестовый сет, данные текущего испытуемого
        #test set, data of current subject
        test_x = np.mean(sub[['GO', word]].get_data(), axis = 2)[:,ch_ind]
        test_y = sub[['GO', word]].events[:,2]
        if overSampTest == True:
            over_sampler = smote_variants.Supervised_SMOTE()
            test_x, test_y = over_sampler.sample(test_x, test_y)
        #перетасовка данных
        #data shuffle
        train_x, train_y = shuffle(train_x, train_y, random_state = 11)
        test_x, test_y = shuffle(test_x, test_y, random_state = 11)
        #обучение fitting
        pipeline.fit(train_x, train_y)
        #тест testing
        y_pred = pipeline.predict(test_x)
        saved_pred.append(y_pred)
        acc_cur.append(accuracy_score(test_y, y_pred))
    accuracies.append(acc_cur)

# %%
accuracies = np.array(accuracies)
#построим результаты точностей 
#build heatmap of resulting loso accuracies
fig2, ax2 = plt.subplots(figsize = (7,7))
im = ax2.imshow(accuracies, cmap="YlGn", vmin = 0.0, vmax = 1.0)
###########################################
ax2.set_yticks(np.arange(accuracies.shape[0]), labels = firstQ.keys(), rotation = 45)
ax2.set_title('LOSO cross-validation')
for i in range(accuracies.shape[0]):
    for j in range(accuracies.shape[1]):
            text = ax2.text(j, i, round(accuracies[i, j], 2),
                           ha="center", va="center", color="black")
fig2.colorbar(im, shrink=0.54)

# %% [markdown]
# <font size="2.7">*Что это всё значит? <br>
# по оси ординат приведены испытуемые, по ориднате слова, в самой ячейке - значение точности и мы видим плохие результаты (едва ли выше случайного порога), но статистическим отбором каналов и нелинейным свм мы добились однордных результатов лосо кросс-валидации*</font>

# %%
#медианная кросс-валидационная точность
#median cross-validation accuracy
np.array([np.mean(accuracies, axis = 1)]).T
#всё плохо, если попробовать классификацию на всех каналах, или на тех, которые дали плохие стат результаты -конечный результат будет таким же (при использовании случайного леса)
# Out:
# array([[0.83910247],
#        [0.95605425],
#        [0.91673708],
#        [0.92786773],
#        [0.91072644],
#        [0.94281171]])

# %%
# import pandas as pd
# for i in range(len(saved_x)):
#     data = pd.DataFrame(np.append(saved_x[i],np.array([saved_y[i]]).T, axis = 1), columns = ['{}'.format(j) if j != saved_x[i].shape[1] else 'label' for j in range(saved_x[i].shape[1] + 1)])
#     sns.pairplot(data, hue = 'label')
#     plt.savefig('/home/dataFolder/Ekizyan/Prior/images/pairplot/fig-{}.png'.format(i))
#     plt.close()

# %% [markdown]
# -----классификация по каждому человеку отдельно, с добавлением нового признака - среднего расстояния между объектами в признаковом пространстве (проблема в том, что не получится посчитать для нового объекта, так как неизвестно, к какому кластеру расстояние считать??? - может посчитать расстояние до тех и для других объектов изнчально?). В итоге получаем матрицу accuracies - выше можно посмотреть на тепловой карте (название сверху неважно) - получились действительно неплохие результаты-----

# %%
#loso результаты плохие, попробуем subject-dependent
overSamp = True
accuracies = []
for w_ind, word in enumerate(firstQ.keys()):
    acc_cur = []
    for indx, sub in enumerate(psd):
        clf = Pipeline([
            ('scaler', StandardScaler()), 
            ('svm', SVC(kernel='rbf', gamma='scale'))
        ])
        ch_ind = np.squeeze(np.argwhere(matchMat[w_ind,:] == 1))
        #тренировочный сет, данные всех испутемых кроме текущего
        #train set, concatenate data of all subjects except current one
        X = np.mean(sub[['GO', word]].get_data(), axis = 2)[:,ch_ind]
        y = sub[['GO', word]].events[:,2]
        if overSamp == True:
            over_sampler = smote_variants.Supervised_SMOTE()
            X, y = over_sampler.sample(X, y)
        data = pd.DataFrame(np.append(X,np.array([y]).T, axis = 1), columns = ['{}'.format(j) if j != X.shape[1] else 'label' for j in range(X.shape[1] + 1)]).sort_values('label').reset_index(drop=True)
        #add new feature - mean distance among points in feature space
        d__ = []
        for l in np.unique(data['label']):
            n = data.loc[data['label'] == l,:].values
            d_ = []
            for i in range(n.shape[0]):
                k = []
                for j in range(n.shape[0]):
                    k.append(np.sqrt((n[i,0] - n[j,0])**2 + (n[i,1] - n[j,1])**2 + (n[i,0] - n[j,0])**2))
                d_.append(np.mean(k))
            d__ = d__ + d_
        data.insert(loc=3, column='3', value=d__)
        train_x, test_x, train_y, test_y = train_test_split(data.iloc[:,:-1], data['label'], test_size=0.33, random_state=42)
        #обучение fitting
        clf.fit(train_x, train_y)
        #тест testing
        y_pred = clf.predict(test_x)
        acc_cur.append(accuracy_score(test_y, y_pred))
    accuracies.append(acc_cur)
        # sns.pairplot(data, hue = 'label')
        # plt.savefig('/home/dataFolder/Ekizyan/Prior/images/pairplot/fig-{}-{}.png'.format(word,indx))
        # plt.close()
# Out:
# 2024-08-23 06:15:57,194:INFO:Supervised_SMOTE: Running sampling via ('Supervised_SMOTE', "{'proportion': 1.0, 'th_lower': 0.5, 'th_upper': 1.0, 'classifier': ('sklearn.ensemble', 'RandomForestClassifier', {'n_estimators': 50, 'n_jobs': 1, 'random_state': 5}), 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Supervised_SMOTE'}")
# 2024-08-23 06:15:57,269:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:15:57,279:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:15:57,288:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:15:57,297:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:15:57,440:INFO:Supervised_SMOTE: Running sampling via ('Supervised_SMOTE', "{'proportion': 1.0, 'th_lower': 0.5, 'th_upper': 1.0, 'classifier': ('sklearn.ensemble', 'RandomForestClassifier', {'n_estimators': 50, 'n_jobs': 1, 'random_state': 5}), 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Supervised_SMOTE'}")
# 2024-08-23 06:15:57,496:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:15:57,502:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:15:57,509:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:15:57,517:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:15:57,522:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:15:57,647:INFO:Supervised_SMOTE: Running sampling via ('Supervised_SMOTE', "{'proportion': 1.0, 'th_lower': 0.5, 'th_upper': 1.0, 'classifier': ('sklearn.ensemble', 'RandomForestClassifier', {'n_estimators': 50, 'n_jobs': 1, 'random_state': 5}), 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Supervised_SMOTE'}")
# 2024-08-23 06:15:57,702:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:15:57,708:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:15:57,717:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:15:57,780:INFO:Supervised_SMOTE: Running sampling via ('Supervised_SMOTE', "{'proportion': 1.0, 'th_lower': 0.5, 'th_upper': 1.0, 'classifier': ('sklearn.ensemble', 'RandomForestClassifier', {'n_estimators': 50, 'n_jobs': 1, 'random_state': 5}), 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Supervised_SMOTE'}")
# 2024-08-23 06:15:57,851:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:15:57,855:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:15:57,859:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:15:57,865:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:15:57,943:INFO:Supervised_SMOTE: Running sampling via ('Supervised_SMOTE', "{'proportion': 1.0, 'th_lower': 0.5, 'th_upper': 1.0, 'classifier': ('sklearn.ensemble', 'RandomForestClassifier', {'n_estimators': 50, 'n_jobs': 1, 'random_state': 5}), 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Supervised_SMOTE'}")
# 2024-08-23 06:15:58,021:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:15:58,025:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:15:58,034:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:15:58,039:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:15:58,108:INFO:Supervised_SMOTE: Running sampling via ('Supervised_SMOTE', "{'proportion': 1.0, 'th_lower': 0.5, 'th_upper': 1.0, 'classifier': ('sklearn.ensemble', 'RandomForestClassifier', {'n_estimators': 50, 'n_jobs': 1, 'random_state': 5}), 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Supervised_SMOTE'}")
# 2024-08-23 06:15:58,165:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:15:58,172:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:15:58,176:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:15:58,181:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:15:58,259:INFO:Supervised_SMOTE: Running sampling via ('Supervised_SMOTE', "{'proportion': 1.0, 'th_lower': 0.5, 'th_upper': 1.0, 'classifier': ('sklearn.ensemble', 'RandomForestClassifier', {'n_estimators': 50, 'n_jobs': 1, 'random_state': 5}), 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Supervised_SMOTE'}")
# 2024-08-23 06:15:58,315:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:15:58,321:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:15:58,326:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:15:58,332:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:15:58,405:INFO:Supervised_SMOTE: Running sampling via ('Supervised_SMOTE', "{'proportion': 1.0, 'th_lower': 0.5, 'th_upper': 1.0, 'classifier': ('sklearn.ensemble', 'RandomForestClassifier', {'n_estimators': 50, 'n_jobs': 1, 'random_state': 5}), 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Supervised_SMOTE'}")
# 2024-08-23 06:15:58,458:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:15:58,466:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:15:58,476:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:15:58,486:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:15:58,559:INFO:Supervised_SMOTE: Running sampling via ('Supervised_SMOTE', "{'proportion': 1.0, 'th_lower': 0.5, 'th_upper': 1.0, 'classifier': ('sklearn.ensemble', 'RandomForestClassifier', {'n_estimators': 50, 'n_jobs': 1, 'random_state': 5}), 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Supervised_SMOTE'}")
# 2024-08-23 06:15:58,628:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:15:58,633:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:15:58,640:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:15:58,702:INFO:Supervised_SMOTE: Running sampling via ('Supervised_SMOTE', "{'proportion': 1.0, 'th_lower': 0.5, 'th_upper': 1.0, 'classifier': ('sklearn.ensemble', 'RandomForestClassifier', {'n_estimators': 50, 'n_jobs': 1, 'random_state': 5}), 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Supervised_SMOTE'}")
# 2024-08-23 06:15:58,757:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:15:58,763:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:15:58,774:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:15:58,785:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:15:58,878:INFO:Supervised_SMOTE: Running sampling via ('Supervised_SMOTE', "{'proportion': 1.0, 'th_lower': 0.5, 'th_upper': 1.0, 'classifier': ('sklearn.ensemble', 'RandomForestClassifier', {'n_estimators': 50, 'n_jobs': 1, 'random_state': 5}), 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Supervised_SMOTE'}")
# 2024-08-23 06:15:58,934:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:15:58,940:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:15:58,947:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:15:58,955:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:15:59,068:INFO:Supervised_SMOTE: Running sampling via ('Supervised_SMOTE', "{'proportion': 1.0, 'th_lower': 0.5, 'th_upper': 1.0, 'classifier': ('sklearn.ensemble', 'RandomForestClassifier', {'n_estimators': 50, 'n_jobs': 1, 'random_state': 5}), 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Supervised_SMOTE'}")
# 2024-08-23 06:15:59,122:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:15:59,131:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:15:59,140:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:15:59,197:INFO:Supervised_SMOTE: Running sampling via ('Supervised_SMOTE', "{'proportion': 1.0, 'th_lower': 0.5, 'th_upper': 1.0, 'classifier': ('sklearn.ensemble', 'RandomForestClassifier', {'n_estimators': 50, 'n_jobs': 1, 'random_state': 5}), 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Supervised_SMOTE'}")
# 2024-08-23 06:15:59,257:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:15:59,265:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:15:59,269:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:15:59,313:INFO:Supervised_SMOTE: Running sampling via ('Supervised_SMOTE', "{'proportion': 1.0, 'th_lower': 0.5, 'th_upper': 1.0, 'classifier': ('sklearn.ensemble', 'RandomForestClassifier', {'n_estimators': 50, 'n_jobs': 1, 'random_state': 5}), 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Supervised_SMOTE'}")
# 2024-08-23 06:15:59,368:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:15:59,373:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:15:59,377:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:15:59,384:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:15:59,498:INFO:Supervised_SMOTE: Running sampling via ('Supervised_SMOTE', "{'proportion': 1.0, 'th_lower': 0.5, 'th_upper': 1.0, 'classifier': ('sklearn.ensemble', 'RandomForestClassifier', {'n_estimators': 50, 'n_jobs': 1, 'random_state': 5}), 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Supervised_SMOTE'}")
# 2024-08-23 06:15:59,552:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:15:59,559:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:15:59,564:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:15:59,569:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:15:59,649:INFO:Supervised_SMOTE: Running sampling via ('Supervised_SMOTE', "{'proportion': 1.0, 'th_lower': 0.5, 'th_upper': 1.0, 'classifier': ('sklearn.ensemble', 'RandomForestClassifier', {'n_estimators': 50, 'n_jobs': 1, 'random_state': 5}), 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Supervised_SMOTE'}")
# 2024-08-23 06:15:59,701:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:15:59,705:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:15:59,710:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:15:59,716:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:15:59,815:INFO:Supervised_SMOTE: Running sampling via ('Supervised_SMOTE', "{'proportion': 1.0, 'th_lower': 0.5, 'th_upper': 1.0, 'classifier': ('sklearn.ensemble', 'RandomForestClassifier', {'n_estimators': 50, 'n_jobs': 1, 'random_state': 5}), 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Supervised_SMOTE'}")
# 2024-08-23 06:15:59,877:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:15:59,881:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:15:59,886:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:15:59,890:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:15:59,959:INFO:Supervised_SMOTE: Running sampling via ('Supervised_SMOTE', "{'proportion': 1.0, 'th_lower': 0.5, 'th_upper': 1.0, 'classifier': ('sklearn.ensemble', 'RandomForestClassifier', {'n_estimators': 50, 'n_jobs': 1, 'random_state': 5}), 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Supervised_SMOTE'}")
# 2024-08-23 06:16:00,017:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:00,023:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:00,026:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:00,035:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:00,100:INFO:Supervised_SMOTE: Running sampling via ('Supervised_SMOTE', "{'proportion': 1.0, 'th_lower': 0.5, 'th_upper': 1.0, 'classifier': ('sklearn.ensemble', 'RandomForestClassifier', {'n_estimators': 50, 'n_jobs': 1, 'random_state': 5}), 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Supervised_SMOTE'}")
# 2024-08-23 06:16:00,153:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:00,158:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:00,162:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:00,167:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:00,275:INFO:Supervised_SMOTE: Running sampling via ('Supervised_SMOTE', "{'proportion': 1.0, 'th_lower': 0.5, 'th_upper': 1.0, 'classifier': ('sklearn.ensemble', 'RandomForestClassifier', {'n_estimators': 50, 'n_jobs': 1, 'random_state': 5}), 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Supervised_SMOTE'}")
# 2024-08-23 06:16:00,329:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:00,335:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:00,340:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:00,345:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:00,350:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:00,483:INFO:Supervised_SMOTE: Running sampling via ('Supervised_SMOTE', "{'proportion': 1.0, 'th_lower': 0.5, 'th_upper': 1.0, 'classifier': ('sklearn.ensemble', 'RandomForestClassifier', {'n_estimators': 50, 'n_jobs': 1, 'random_state': 5}), 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Supervised_SMOTE'}")
# 2024-08-23 06:16:00,537:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:00,541:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:00,553:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:00,601:INFO:Supervised_SMOTE: Running sampling via ('Supervised_SMOTE', "{'proportion': 1.0, 'th_lower': 0.5, 'th_upper': 1.0, 'classifier': ('sklearn.ensemble', 'RandomForestClassifier', {'n_estimators': 50, 'n_jobs': 1, 'random_state': 5}), 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Supervised_SMOTE'}")
# 2024-08-23 06:16:00,657:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:00,660:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:00,664:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:00,722:INFO:Supervised_SMOTE: Running sampling via ('Supervised_SMOTE', "{'proportion': 1.0, 'th_lower': 0.5, 'th_upper': 1.0, 'classifier': ('sklearn.ensemble', 'RandomForestClassifier', {'n_estimators': 50, 'n_jobs': 1, 'random_state': 5}), 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Supervised_SMOTE'}")
# 2024-08-23 06:16:00,777:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:00,782:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:00,788:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:00,797:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:00,807:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:00,957:INFO:Supervised_SMOTE: Running sampling via ('Supervised_SMOTE', "{'proportion': 1.0, 'th_lower': 0.5, 'th_upper': 1.0, 'classifier': ('sklearn.ensemble', 'RandomForestClassifier', {'n_estimators': 50, 'n_jobs': 1, 'random_state': 5}), 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Supervised_SMOTE'}")
# 2024-08-23 06:16:01,012:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:01,016:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:01,021:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:01,025:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:01,116:INFO:Supervised_SMOTE: Running sampling via ('Supervised_SMOTE', "{'proportion': 1.0, 'th_lower': 0.5, 'th_upper': 1.0, 'classifier': ('sklearn.ensemble', 'RandomForestClassifier', {'n_estimators': 50, 'n_jobs': 1, 'random_state': 5}), 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Supervised_SMOTE'}")
# 2024-08-23 06:16:01,169:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:01,173:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:01,183:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:01,192:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:01,290:INFO:Supervised_SMOTE: Running sampling via ('Supervised_SMOTE', "{'proportion': 1.0, 'th_lower': 0.5, 'th_upper': 1.0, 'classifier': ('sklearn.ensemble', 'RandomForestClassifier', {'n_estimators': 50, 'n_jobs': 1, 'random_state': 5}), 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Supervised_SMOTE'}")
# 2024-08-23 06:16:01,343:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:01,347:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:01,351:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:01,357:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:01,471:INFO:Supervised_SMOTE: Running sampling via ('Supervised_SMOTE', "{'proportion': 1.0, 'th_lower': 0.5, 'th_upper': 1.0, 'classifier': ('sklearn.ensemble', 'RandomForestClassifier', {'n_estimators': 50, 'n_jobs': 1, 'random_state': 5}), 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Supervised_SMOTE'}")
# 2024-08-23 06:16:01,547:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:01,554:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:01,559:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:01,564:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:01,626:INFO:Supervised_SMOTE: Running sampling via ('Supervised_SMOTE', "{'proportion': 1.0, 'th_lower': 0.5, 'th_upper': 1.0, 'classifier': ('sklearn.ensemble', 'RandomForestClassifier', {'n_estimators': 50, 'n_jobs': 1, 'random_state': 5}), 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Supervised_SMOTE'}")
# 2024-08-23 06:16:01,680:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:01,685:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:01,693:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:01,701:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:01,778:INFO:Supervised_SMOTE: Running sampling via ('Supervised_SMOTE', "{'proportion': 1.0, 'th_lower': 0.5, 'th_upper': 1.0, 'classifier': ('sklearn.ensemble', 'RandomForestClassifier', {'n_estimators': 50, 'n_jobs': 1, 'random_state': 5}), 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Supervised_SMOTE'}")
# 2024-08-23 06:16:01,833:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:01,838:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:01,842:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:01,849:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:01,859:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:02,062:INFO:Supervised_SMOTE: Running sampling via ('Supervised_SMOTE', "{'proportion': 1.0, 'th_lower': 0.5, 'th_upper': 1.0, 'classifier': ('sklearn.ensemble', 'RandomForestClassifier', {'n_estimators': 50, 'n_jobs': 1, 'random_state': 5}), 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Supervised_SMOTE'}")
# 2024-08-23 06:16:02,116:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:02,120:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:02,124:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:02,157:INFO:Supervised_SMOTE: Running sampling via ('Supervised_SMOTE', "{'proportion': 1.0, 'th_lower': 0.5, 'th_upper': 1.0, 'classifier': ('sklearn.ensemble', 'RandomForestClassifier', {'n_estimators': 50, 'n_jobs': 1, 'random_state': 5}), 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Supervised_SMOTE'}")
# 2024-08-23 06:16:02,210:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:02,213:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:02,217:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:02,271:INFO:Supervised_SMOTE: Running sampling via ('Supervised_SMOTE', "{'proportion': 1.0, 'th_lower': 0.5, 'th_upper': 1.0, 'classifier': ('sklearn.ensemble', 'RandomForestClassifier', {'n_estimators': 50, 'n_jobs': 1, 'random_state': 5}), 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Supervised_SMOTE'}")
# 2024-08-23 06:16:02,324:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:02,329:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:02,334:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:02,341:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:02,426:INFO:Supervised_SMOTE: Running sampling via ('Supervised_SMOTE', "{'proportion': 1.0, 'th_lower': 0.5, 'th_upper': 1.0, 'classifier': ('sklearn.ensemble', 'RandomForestClassifier', {'n_estimators': 50, 'n_jobs': 1, 'random_state': 5}), 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Supervised_SMOTE'}")
# 2024-08-23 06:16:02,479:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:02,485:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:02,491:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:02,499:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:02,597:INFO:Supervised_SMOTE: Running sampling via ('Supervised_SMOTE', "{'proportion': 1.0, 'th_lower': 0.5, 'th_upper': 1.0, 'classifier': ('sklearn.ensemble', 'RandomForestClassifier', {'n_estimators': 50, 'n_jobs': 1, 'random_state': 5}), 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Supervised_SMOTE'}")
# 2024-08-23 06:16:02,650:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:02,654:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:02,657:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:02,661:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:02,755:INFO:Supervised_SMOTE: Running sampling via ('Supervised_SMOTE', "{'proportion': 1.0, 'th_lower': 0.5, 'th_upper': 1.0, 'classifier': ('sklearn.ensemble', 'RandomForestClassifier', {'n_estimators': 50, 'n_jobs': 1, 'random_state': 5}), 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Supervised_SMOTE'}")
# 2024-08-23 06:16:02,807:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:02,812:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:02,818:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:02,823:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:02,885:INFO:Supervised_SMOTE: Running sampling via ('Supervised_SMOTE', "{'proportion': 1.0, 'th_lower': 0.5, 'th_upper': 1.0, 'classifier': ('sklearn.ensemble', 'RandomForestClassifier', {'n_estimators': 50, 'n_jobs': 1, 'random_state': 5}), 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Supervised_SMOTE'}")
# 2024-08-23 06:16:02,949:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:02,953:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:02,957:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:03,009:INFO:Supervised_SMOTE: Running sampling via ('Supervised_SMOTE', "{'proportion': 1.0, 'th_lower': 0.5, 'th_upper': 1.0, 'classifier': ('sklearn.ensemble', 'RandomForestClassifier', {'n_estimators': 50, 'n_jobs': 1, 'random_state': 5}), 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Supervised_SMOTE'}")
# 2024-08-23 06:16:03,066:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:03,070:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:03,074:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:03,078:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:03,166:INFO:Supervised_SMOTE: Running sampling via ('Supervised_SMOTE', "{'proportion': 1.0, 'th_lower': 0.5, 'th_upper': 1.0, 'classifier': ('sklearn.ensemble', 'RandomForestClassifier', {'n_estimators': 50, 'n_jobs': 1, 'random_state': 5}), 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Supervised_SMOTE'}")
# 2024-08-23 06:16:03,224:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:03,229:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:03,235:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:03,240:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:03,244:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:03,389:INFO:Supervised_SMOTE: Running sampling via ('Supervised_SMOTE', "{'proportion': 1.0, 'th_lower': 0.5, 'th_upper': 1.0, 'classifier': ('sklearn.ensemble', 'RandomForestClassifier', {'n_estimators': 50, 'n_jobs': 1, 'random_state': 5}), 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Supervised_SMOTE'}")
# 2024-08-23 06:16:03,448:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:03,458:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:03,464:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:03,510:INFO:Supervised_SMOTE: Running sampling via ('Supervised_SMOTE', "{'proportion': 1.0, 'th_lower': 0.5, 'th_upper': 1.0, 'classifier': ('sklearn.ensemble', 'RandomForestClassifier', {'n_estimators': 50, 'n_jobs': 1, 'random_state': 5}), 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Supervised_SMOTE'}")
# 2024-08-23 06:16:03,565:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:03,569:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:03,572:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:03,611:INFO:Supervised_SMOTE: Running sampling via ('Supervised_SMOTE', "{'proportion': 1.0, 'th_lower': 0.5, 'th_upper': 1.0, 'classifier': ('sklearn.ensemble', 'RandomForestClassifier', {'n_estimators': 50, 'n_jobs': 1, 'random_state': 5}), 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Supervised_SMOTE'}")
# 2024-08-23 06:16:03,677:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:03,682:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:03,688:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:03,695:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:03,700:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:03,836:INFO:Supervised_SMOTE: Running sampling via ('Supervised_SMOTE', "{'proportion': 1.0, 'th_lower': 0.5, 'th_upper': 1.0, 'classifier': ('sklearn.ensemble', 'RandomForestClassifier', {'n_estimators': 50, 'n_jobs': 1, 'random_state': 5}), 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Supervised_SMOTE'}")
# 2024-08-23 06:16:03,892:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:03,899:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:03,904:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:03,914:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:03,981:INFO:Supervised_SMOTE: Running sampling via ('Supervised_SMOTE', "{'proportion': 1.0, 'th_lower': 0.5, 'th_upper': 1.0, 'classifier': ('sklearn.ensemble', 'RandomForestClassifier', {'n_estimators': 50, 'n_jobs': 1, 'random_state': 5}), 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Supervised_SMOTE'}")
# 2024-08-23 06:16:04,048:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:04,054:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:04,059:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:04,068:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:04,154:INFO:Supervised_SMOTE: Running sampling via ('Supervised_SMOTE', "{'proportion': 1.0, 'th_lower': 0.5, 'th_upper': 1.0, 'classifier': ('sklearn.ensemble', 'RandomForestClassifier', {'n_estimators': 50, 'n_jobs': 1, 'random_state': 5}), 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Supervised_SMOTE'}")
# 2024-08-23 06:16:04,218:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:04,222:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:04,227:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:04,231:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:04,324:INFO:Supervised_SMOTE: Running sampling via ('Supervised_SMOTE', "{'proportion': 1.0, 'th_lower': 0.5, 'th_upper': 1.0, 'classifier': ('sklearn.ensemble', 'RandomForestClassifier', {'n_estimators': 50, 'n_jobs': 1, 'random_state': 5}), 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Supervised_SMOTE'}")
# 2024-08-23 06:16:04,382:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:04,388:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:04,393:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:04,466:INFO:Supervised_SMOTE: Running sampling via ('Supervised_SMOTE', "{'proportion': 1.0, 'th_lower': 0.5, 'th_upper': 1.0, 'classifier': ('sklearn.ensemble', 'RandomForestClassifier', {'n_estimators': 50, 'n_jobs': 1, 'random_state': 5}), 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Supervised_SMOTE'}")
# 2024-08-23 06:16:04,519:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:04,523:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:04,527:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:04,533:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:04,623:INFO:Supervised_SMOTE: Running sampling via ('Supervised_SMOTE', "{'proportion': 1.0, 'th_lower': 0.5, 'th_upper': 1.0, 'classifier': ('sklearn.ensemble', 'RandomForestClassifier', {'n_estimators': 50, 'n_jobs': 1, 'random_state': 5}), 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Supervised_SMOTE'}")
# 2024-08-23 06:16:04,681:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:04,685:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:04,688:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:04,692:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:04,806:INFO:Supervised_SMOTE: Running sampling via ('Supervised_SMOTE', "{'proportion': 1.0, 'th_lower': 0.5, 'th_upper': 1.0, 'classifier': ('sklearn.ensemble', 'RandomForestClassifier', {'n_estimators': 50, 'n_jobs': 1, 'random_state': 5}), 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Supervised_SMOTE'}")
# 2024-08-23 06:16:04,861:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:04,869:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:04,874:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:04,927:INFO:Supervised_SMOTE: Running sampling via ('Supervised_SMOTE', "{'proportion': 1.0, 'th_lower': 0.5, 'th_upper': 1.0, 'classifier': ('sklearn.ensemble', 'RandomForestClassifier', {'n_estimators': 50, 'n_jobs': 1, 'random_state': 5}), 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Supervised_SMOTE'}")
# 2024-08-23 06:16:04,980:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:04,985:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:04,993:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:05,049:INFO:Supervised_SMOTE: Running sampling via ('Supervised_SMOTE', "{'proportion': 1.0, 'th_lower': 0.5, 'th_upper': 1.0, 'classifier': ('sklearn.ensemble', 'RandomForestClassifier', {'n_estimators': 50, 'n_jobs': 1, 'random_state': 5}), 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Supervised_SMOTE'}")
# 2024-08-23 06:16:05,102:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:05,108:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:05,113:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:05,116:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:05,211:INFO:Supervised_SMOTE: Running sampling via ('Supervised_SMOTE', "{'proportion': 1.0, 'th_lower': 0.5, 'th_upper': 1.0, 'classifier': ('sklearn.ensemble', 'RandomForestClassifier', {'n_estimators': 50, 'n_jobs': 1, 'random_state': 5}), 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Supervised_SMOTE'}")
# 2024-08-23 06:16:05,276:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:05,280:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:05,285:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:05,291:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:05,419:INFO:Supervised_SMOTE: Running sampling via ('Supervised_SMOTE', "{'proportion': 1.0, 'th_lower': 0.5, 'th_upper': 1.0, 'classifier': ('sklearn.ensemble', 'RandomForestClassifier', {'n_estimators': 50, 'n_jobs': 1, 'random_state': 5}), 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Supervised_SMOTE'}")
# 2024-08-23 06:16:05,471:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:05,476:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:05,480:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:05,486:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:05,562:INFO:Supervised_SMOTE: Running sampling via ('Supervised_SMOTE', "{'proportion': 1.0, 'th_lower': 0.5, 'th_upper': 1.0, 'classifier': ('sklearn.ensemble', 'RandomForestClassifier', {'n_estimators': 50, 'n_jobs': 1, 'random_state': 5}), 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Supervised_SMOTE'}")
# 2024-08-23 06:16:05,614:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:05,620:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:05,626:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:05,636:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:05,718:INFO:Supervised_SMOTE: Running sampling via ('Supervised_SMOTE', "{'proportion': 1.0, 'th_lower': 0.5, 'th_upper': 1.0, 'classifier': ('sklearn.ensemble', 'RandomForestClassifier', {'n_estimators': 50, 'n_jobs': 1, 'random_state': 5}), 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Supervised_SMOTE'}")
# 2024-08-23 06:16:05,773:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:05,778:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:05,783:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-08-23 06:16:05,791:INFO:Supervised_SMOTE: simplex sampling with n_dim 2

# %%
#получаются хорошие результаты, особенно после добавления нового признака
print('Среднее по словам \n',np.array([np.mean(accuracies, axis = 1)]).T)
print('Среднее по людям \n',np.array([np.mean(accuracies, axis = 0)]).T)
# Out:
# Среднее по словам
#  [[0.92635776]
#  [0.98409031]
#  [0.95489266]
#  [0.91405137]
#  [0.92713894]
#  [0.93373683]]
# Среднее по людям
#  [[0.93969617]
#  [0.91293286]
#  [0.920588  ]
#  [0.93736636]
#  [0.94163586]
#  [0.98521967]
#  [0.99826389]
#  [0.93981481]
#  [0.88488421]]

# %% [markdown]
# -----попробуем объеденить слова в один общий класс - в конце концов, все они слова братушки, классификацию пока не тестил, строил только диаграммы рассения, попробовал построить линейную регрессию по мнк и посчитать расстояния до прямой в двух классах. По диаграммам рассеяния можно увидеть не очень хорошие показатели, такие данны вряд ли получится как то разделить, 1 проблема - когда объединяешь слова в один класс проб фона становится кратно меньше, чем данных слов, что просто не позволит никакой модели обощиться 2 - можно заоверсэмплить, но тут методов под сотню и метод методу рознь (хотя возможно ситуация изменится, если отбросить выбросы??) 3 - поставить весы классов? - обычно после этого не работает ничего)))). После длительных плясок с бубном с разными частотными диапазонами, решено было досчитать возможно всё средние по всем частотам, отношения мощностей диапазонов, когерентность??? - свалим всё в одну кучу, потом отберем каким нибудь стат. анализом, например.-----

# %%
#надо попробовать объеденить слова в один класс
overSamp = True
accuracies = []
pal = sns.color_palette("hls", 7)
for indx, sub in enumerate(psd):
    #ch_ind = np.squeeze(np.argwhere(matchMat[w_ind,:] == 1))
    #ch_ind = np.arange(sub['GO'].get_data().shape[1])
    #rest state
    ch_ind = np.squeeze(np.argwhere(np.sum(matchMat, axis = 0) != 0))
    X_fon = np.mean(sub['GO'].get_data(), axis = 2)[:,ch_ind]
    y_fon = np.zeros((X_fon.shape[0]))
    #all word mean spectrums to one
    epoWords = sub[[w for w in getList(sub.event_id) if w != 'GO']].get_data()
    X_word = np.mean(epoWords, axis = 2)[:,ch_ind]
    #should calc smth besides mean
    std = np.std(epoWords, axis = 2)[:,ch_ind]
    ptp = np.ptp(epoWords, axis = 2)[:,ch_ind]
    kurt = stats.kurtosis(epoWords, axis = 2)[:,ch_ind]
    skew = stats.skew(epoWords, axis = 2)[:,ch_ind]
    X_stats = np.concatenate([std,ptp,kurt,skew], axis = 1)
    
    #y_word = np.ones((X_word.shape[0]))
    y_word = sub[[w for w in getList(sub.event_id) if w != 'GO']].events[:,2]
    
    X = np.concatenate([X_fon, X_word])
    y = np.concatenate([y_fon, y_word])
    #oversampling
    if overSamp == True:
        over_sampler = smote_variants.Supervised_SMOTE()
        X, y = over_sampler.sample(X, y)
    #scaling
    sc = StandardScaler()
    X = sc.fit_transform(X,y)
    #form a dataframe for pairplot
    data = pd.DataFrame(np.append(X,np.array([y]).T, axis = 1), columns = ['{}'.format(j) if j != X.shape[1] else 'label' for j in range(X.shape[1] + 1)]).sort_values('label').reset_index(drop=True)
    
    #linear approximation based features
    regres = []
    pair = list(combinations(range(X.shape[1]), 2))
    for p in pair:
        line = []
        vecs = []
        weighted_d = []
        for l in np.unique(data['label']):
            n = data.loc[data['label'] == l,:].values
            slope, interc, _,_,_ = stats.linregress(n[:,p[0]], n[:,p[1]])
            line.append([slope, interc])
        for i,j in zip(data.values[:,p[0]], data.values[:,p[1]]):
            #weighted according to class relation distance to linear approxiamtion line
            p1 = np.array([0,0])
            y21 = line[0][0]*i + line[0][1]
            y22 = line[1][0]*i + line[1][1]
            p21 = np.array([i, y21])
            p22 = np.array([i, y22])
            p3 = np.array([i,j])
            d1 = np.cross(p21 - p1, p3 - p1) / np.linalg.norm(p21 - p1)
            d2 = np.cross(p22 - p1, p3 - p1) / np.linalg.norm(p22 - p1)
            weighted_d.append([-2*d1 + d2])
        regres.append(weighted_d)
    regres = np.squeeze(np.array(regres)).T
    #data = pd.DataFrame(np.append(regres,np.array([y]).T, axis = 1), columns = ['{}'.format(j) if j != regres.shape[1] else 'label' for j in range(regres.shape[1] + 1)]).sort_values('label').reset_index(drop=True)
    #covariance eeg features based on distance to cov eigenvectors

    #pca projections
    pca = KernelPCA(kernel = 'rbf',n_components = 2)
    X_pca = pd.DataFrame(pca.fit_transform(X), columns = ['pca_1','pca_2'])
    #ica projections
    ica = FastICA(n_components = 2)
    X_ica = pd.DataFrame(ica.fit_transform(X), columns = ['ica_1','ica_2'])
    #stats frame
    names = ['std_{}','ptp_{}','kurt_{}','skew_{}']
    X_stats = pd.DataFrame(X_stats, columns = np.concatenate([[stat.format(i) for i in range(3)] for stat in names]))
    #append to main dataframe
    data = pd.concat([data, X_pca, X_stats], axis = 1)
    
    sns.pairplot(data, hue = 'label',palette = pal)
    plt.savefig('/home/dataFolder/Ekizyan/Prior/images/pairplot/fig-{}.png'.format(indx))
    plt.close()
# Out:
# 2024-09-02 09:57:09,288:INFO:Supervised_SMOTE: Running sampling via ('Supervised_SMOTE', "{'proportion': 1.0, 'th_lower': 0.5, 'th_upper': 1.0, 'classifier': ('sklearn.ensemble', 'RandomForestClassifier', {'n_estimators': 50, 'n_jobs': 1, 'random_state': 5}), 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Supervised_SMOTE'}")
# 2024-09-02 09:57:09,346:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-09-02 09:57:09,352:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-09-02 09:57:09,363:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-09-02 09:57:09,368:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-09-02 09:57:09,374:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-09-02 09:57:09,378:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-09-02 09:58:13,995:INFO:Supervised_SMOTE: Running sampling via ('Supervised_SMOTE', "{'proportion': 1.0, 'th_lower': 0.5, 'th_upper': 1.0, 'classifier': ('sklearn.ensemble', 'RandomForestClassifier', {'n_estimators': 50, 'n_jobs': 1, 'random_state': 5}), 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Supervised_SMOTE'}")
# 2024-09-02 09:58:14,079:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-09-02 09:58:14,085:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-09-02 09:58:14,090:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-09-02 09:58:14,095:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-09-02 09:58:14,101:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-09-02 09:58:14,109:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-09-02 09:59:22,695:INFO:Supervised_SMOTE: Running sampling via ('Supervised_SMOTE', "{'proportion': 1.0, 'th_lower': 0.5, 'th_upper': 1.0, 'classifier': ('sklearn.ensemble', 'RandomForestClassifier', {'n_estimators': 50, 'n_jobs': 1, 'random_state': 5}), 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Supervised_SMOTE'}")
# 2024-09-02 09:59:22,754:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-09-02 09:59:22,760:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-09-02 09:59:22,765:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-09-02 09:59:22,772:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-09-02 09:59:22,781:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-09-02 09:59:22,785:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-09-02 10:00:24,894:INFO:Supervised_SMOTE: Running sampling via ('Supervised_SMOTE', "{'proportion': 1.0, 'th_lower': 0.5, 'th_upper': 1.0, 'classifier': ('sklearn.ensemble', 'RandomForestClassifier', {'n_estimators': 50, 'n_jobs': 1, 'random_state': 5}), 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Supervised_SMOTE'}")
# 2024-09-02 10:00:24,951:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-09-02 10:00:24,957:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-09-02 10:00:24,962:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-09-02 10:00:24,972:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-09-02 10:00:24,981:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-09-02 10:00:24,987:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-09-02 10:01:28,205:INFO:Supervised_SMOTE: Running sampling via ('Supervised_SMOTE', "{'proportion': 1.0, 'th_lower': 0.5, 'th_upper': 1.0, 'classifier': ('sklearn.ensemble', 'RandomForestClassifier', {'n_estimators': 50, 'n_jobs': 1, 'random_state': 5}), 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Supervised_SMOTE'}")
# 2024-09-02 10:01:28,288:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-09-02 10:01:28,293:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-09-02 10:01:28,298:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-09-02 10:01:28,303:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-09-02 10:01:28,308:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-09-02 10:01:28,314:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-09-02 10:02:35,440:INFO:Supervised_SMOTE: Running sampling via ('Supervised_SMOTE', "{'proportion': 1.0, 'th_lower': 0.5, 'th_upper': 1.0, 'classifier': ('sklearn.ensemble', 'RandomForestClassifier', {'n_estimators': 50, 'n_jobs': 1, 'random_state': 5}), 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Supervised_SMOTE'}")
# 2024-09-02 10:02:35,501:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-09-02 10:02:35,506:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-09-02 10:02:35,512:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-09-02 10:02:35,521:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-09-02 10:02:35,529:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-09-02 10:02:35,533:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-09-02 10:03:39,099:INFO:Supervised_SMOTE: Running sampling via ('Supervised_SMOTE', "{'proportion': 1.0, 'th_lower': 0.5, 'th_upper': 1.0, 'classifier': ('sklearn.ensemble', 'RandomForestClassifier', {'n_estimators': 50, 'n_jobs': 1, 'random_state': 5}), 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Supervised_SMOTE'}")
# 2024-09-02 10:03:39,181:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-09-02 10:03:39,186:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-09-02 10:03:39,190:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-09-02 10:03:39,195:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-09-02 10:03:39,201:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-09-02 10:03:39,205:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-09-02 10:04:46,002:INFO:Supervised_SMOTE: Running sampling via ('Supervised_SMOTE', "{'proportion': 1.0, 'th_lower': 0.5, 'th_upper': 1.0, 'classifier': ('sklearn.ensemble', 'RandomForestClassifier', {'n_estimators': 50, 'n_jobs': 1, 'random_state': 5}), 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Supervised_SMOTE'}")
# 2024-09-02 10:04:46,065:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-09-02 10:04:46,071:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-09-02 10:04:46,076:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-09-02 10:04:46,084:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-09-02 10:04:46,093:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-09-02 10:04:46,098:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-09-02 10:05:55,361:INFO:Supervised_SMOTE: Running sampling via ('Supervised_SMOTE', "{'proportion': 1.0, 'th_lower': 0.5, 'th_upper': 1.0, 'classifier': ('sklearn.ensemble', 'RandomForestClassifier', {'n_estimators': 50, 'n_jobs': 1, 'random_state': 5}), 'n_jobs': 1, 'ss_params': {'n_dim': 2, 'simplex_sampling': 'random', 'within_simplex_sampling': 'random', 'gaussian_component': {}}, 'random_state': None, 'class_name': 'Supervised_SMOTE'}")
# 2024-09-02 10:05:55,422:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-09-02 10:05:55,427:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-09-02 10:05:55,431:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-09-02 10:05:55,437:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-09-02 10:05:55,441:INFO:Supervised_SMOTE: simplex sampling with n_dim 2
# 2024-09-02 10:05:55,446:INFO:Supervised_SMOTE: simplex sampling with n_dim 2

# %%
#построили, посмотрели, разочаровались 
#возможно стоит проделать стат анализ, с объединенными данными слов?

# %% [markdown]
# запускать код с расчетом когерентности, если нет файла с ними (в хабе есть - выполняйте след ячейку. условия писать лень)

# %%
#давайте считать когерентность. Метод, используемый в mne для одиночных эпох считает очень очень долго. Возможно если написать самому без тфр будет быстрее
allCoh = {}
for sub_ind, sub in enumerate(epoData):
    print('Starting coherence calc for subject-{}'.format(sub_ind))
    labCoh = {}
    for lab_ind, label in enumerate(getList(sub.event_id)):
        print('Starting coherence calc for class--({})-- ...'.format(label))
        uniq_ch = list(combinations(sub.ch_names, 2))
        uniq_ch_ind = list(combinations(range(len(sub.ch_names)), 2))
        epoCoh = []
        for epoch in sub[label].get_data():
            nperseg = epoch.shape[1] // 2
            pairCoh = []
            for pair in uniq_ch_ind:
                f, Cxy = signal.coherence(epoch[pair[0],:], epoch[pair[1],:],fs = 500, nperseg = nperseg)
                Cxy = np.array([Cxy[np.where(f<70)[0]]])
                pairCoh.append(Cxy)
            pairCoh = np.expand_dims(np.concatenate(pairCoh, axis = 0), axis = 0)
            epoCoh.append(pairCoh)
        epoCoh = np.concatenate(epoCoh, axis = 0)
        labCoh[label] = epoCoh
    allCoh[sub_ind] = labCoh
print('Calculation done.')
# Out:
# Starting coherence calc for subject-0
# Starting coherence calc for class--(BACK1)-- ...
# Loading data for 168 events and 500 original time points ...
# Starting coherence calc for class--(BACK2)-- ...
# Loading data for 125 events and 500 original time points ...
# Starting coherence calc for class--(DOWN1)-- ...
# Loading data for 127 events and 500 original time points ...
# Starting coherence calc for class--(DOWN2)-- ...
# Loading data for 126 events and 500 original time points ...
# Starting coherence calc for class--(FORWARD1)-- ...
# Loading data for 154 events and 500 original time points ...
# Starting coherence calc for class--(FORWARD2)-- ...
# Loading data for 151 events and 500 original time points ...
# Starting coherence calc for class--(GO)-- ...
# Loading data for 40 events and 500 original time points ...
# Starting coherence calc for class--(LEFT1)-- ...
# Loading data for 121 events and 500 original time points ...
# Starting coherence calc for class--(LEFT2)-- ...
# Loading data for 116 events and 500 original time points ...
# Starting coherence calc for class--(RIGHT1)-- ...
# Loading data for 133 events and 500 original time points ...
# Starting coherence calc for class--(RIGHT2)-- ...
# Loading data for 131 events and 500 original time points ...
# Starting coherence calc for class--(UP1)-- ...
# Loading data for 107 events and 500 original time points ...
# Starting coherence calc for class--(UP2)-- ...
# Loading data for 112 events and 500 original time points ...
# Starting coherence calc for subject-1
# Starting coherence calc for class--(BACK1)-- ...
# Loading data for 165 events and 500 original time points ...
# Starting coherence calc for class--(BACK2)-- ...
# Loading data for 169 events and 500 original time points ...
# Starting coherence calc for class--(DOWN1)-- ...
# Loading data for 181 events and 500 original time points ...
# Starting coherence calc for class--(DOWN2)-- ...
# Loading data for 151 events and 500 original time points ...
# Starting coherence calc for class--(FORWARD1)-- ...
# Loading data for 226 events and 500 original time points ...
# Starting coherence calc for class--(FORWARD2)-- ...
# Loading data for 175 events and 500 original time points ...
# Starting coherence calc for class--(GO)-- ...
# Loading data for 40 events and 500 original time points ...
# Starting coherence calc for class--(LEFT1)-- ...
# Loading data for 148 events and 500 original time points ...
# Starting coherence calc for class--(LEFT2)-- ...
# Loading data for 211 events and 500 original time points ...
# Starting coherence calc for class--(RIGHT1)-- ...
# Loading data for 168 events and 500 original time points ...
# Starting coherence calc for class--(RIGHT2)-- ...
# Loading data for 182 events and 500 original time points ...
# Starting coherence calc for class--(UP1)-- ...
# Loading data for 214 events and 500 original time points ...
# Starting coherence calc for class--(UP2)-- ...
# Loading data for 158 events and 500 original time points ...
# Starting coherence calc for subject-2
# Starting coherence calc for class--(BACK1)-- ...
# Loading data for 88 events and 500 original time points ...
# Starting coherence calc for class--(BACK2)-- ...
# Loading data for 89 events and 500 original time points ...
# Starting coherence calc for class--(DOWN1)-- ...
# Loading data for 89 events and 500 original time points ...
# Starting coherence calc for class--(DOWN2)-- ...
# Loading data for 84 events and 500 original time points ...
# Starting coherence calc for class--(FORWARD1)-- ...
# Loading data for 88 events and 500 original time points ...
# Starting coherence calc for class--(FORWARD2)-- ...
# Loading data for 86 events and 500 original time points ...
# Starting coherence calc for class--(GO)-- ...
# Loading data for 40 events and 500 original time points ...
# Starting coherence calc for class--(LEFT1)-- ...
# Loading data for 106 events and 500 original time points ...
# Starting coherence calc for class--(LEFT2)-- ...
# Loading data for 61 events and 500 original time points ...
# Starting coherence calc for class--(RIGHT1)-- ...
# Loading data for 86 events and 500 original time points ...
# Starting coherence calc for class--(RIGHT2)-- ...
# Loading data for 84 events and 500 original time points ...
# Starting coherence calc for class--(UP1)-- ...
# Loading data for 94 events and 500 original time points ...
# Starting coherence calc for class--(UP2)-- ...
# Loading data for 86 events and 500 original time points ...
# Starting coherence calc for subject-3
# Starting coherence calc for class--(BACK1)-- ...
# Loading data for 92 events and 500 original time points ...
# Starting coherence calc for class--(BACK2)-- ...
# Loading data for 100 events and 500 original time points ...
# Starting coherence calc for class--(DOWN1)-- ...
# Loading data for 95 events and 500 original time points ...
# Starting coherence calc for class--(DOWN2)-- ...
# Loading data for 75 events and 500 original time points ...
# Starting coherence calc for class--(FORWARD1)-- ...
# Loading data for 98 events and 500 original time points ...
# Starting coherence calc for class--(FORWARD2)-- ...
# Loading data for 95 events and 500 original time points ...
# Starting coherence calc for class--(GO)-- ...
# Loading data for 40 events and 500 original time points ...
# Starting coherence calc for class--(LEFT1)-- ...
# Loading data for 110 events and 500 original time points ...
# Starting coherence calc for class--(LEFT2)-- ...
# Loading data for 94 events and 500 original time points ...
# Starting coherence calc for class--(RIGHT1)-- ...
# Loading data for 89 events and 500 original time points ...
# Starting coherence calc for class--(RIGHT2)-- ...
# Loading data for 70 events and 500 original time points ...
# Starting coherence calc for class--(UP1)-- ...
# Loading data for 99 events and 500 original time points ...
# Starting coherence calc for class--(UP2)-- ...
# Loading data for 91 events and 500 original time points ...
# Starting coherence calc for subject-4
# Starting coherence calc for class--(BACK1)-- ...
# Loading data for 102 events and 500 original time points ...
# Starting coherence calc for class--(BACK2)-- ...
# Loading data for 113 events and 500 original time points ...
# Starting coherence calc for class--(DOWN1)-- ...
# Loading data for 117 events and 500 original time points ...
# Starting coherence calc for class--(DOWN2)-- ...
# Loading data for 156 events and 500 original time points ...
# Starting coherence calc for class--(FORWARD1)-- ...
# Loading data for 142 events and 500 original time points ...
# Starting coherence calc for class--(FORWARD2)-- ...
# Loading data for 185 events and 500 original time points ...
# Starting coherence calc for class--(GO)-- ...
# Loading data for 40 events and 500 original time points ...
# Starting coherence calc for class--(LEFT1)-- ...
# Loading data for 143 events and 500 original time points ...
# Starting coherence calc for class--(LEFT2)-- ...
# Loading data for 128 events and 500 original time points ...
# Starting coherence calc for class--(RIGHT1)-- ...
# Loading data for 122 events and 500 original time points ...
# Starting coherence calc for class--(RIGHT2)-- ...
# Loading data for 176 events and 500 original time points ...
# Starting coherence calc for class--(UP1)-- ...
# Loading data for 73 events and 500 original time points ...
# Starting coherence calc for class--(UP2)-- ...
# Loading data for 140 events and 500 original time points ...
# Starting coherence calc for subject-5
# Starting coherence calc for class--(BACK1)-- ...
# Loading data for 115 events and 500 original time points ...
# Starting coherence calc for class--(BACK2)-- ...
# Loading data for 119 events and 500 original time points ...
# Starting coherence calc for class--(DOWN1)-- ...
# Loading data for 115 events and 500 original time points ...
# Starting coherence calc for class--(DOWN2)-- ...
# Loading data for 124 events and 500 original time points ...
# Starting coherence calc for class--(FORWARD1)-- ...
# Loading data for 132 events and 500 original time points ...
# Starting coherence calc for class--(FORWARD2)-- ...
# Loading data for 136 events and 500 original time points ...
# Starting coherence calc for class--(GO)-- ...
# Loading data for 40 events and 500 original time points ...
# Starting coherence calc for class--(LEFT1)-- ...
# Loading data for 131 events and 500 original time points ...
# Starting coherence calc for class--(LEFT2)-- ...
# Loading data for 115 events and 500 original time points ...
# Starting coherence calc for class--(RIGHT1)-- ...
# Loading data for 106 events and 500 original time points ...
# Starting coherence calc for class--(RIGHT2)-- ...
# Loading data for 108 events and 500 original time points ...
# Starting coherence calc for class--(UP1)-- ...
# Loading data for 131 events and 500 original time points ...
# Starting coherence calc for class--(UP2)-- ...
# Loading data for 160 events and 500 original time points ...
# Starting coherence calc for subject-6
# Starting coherence calc for class--(BACK1)-- ...
# Loading data for 132 events and 500 original time points ...
# Starting coherence calc for class--(BACK2)-- ...
# Loading data for 113 events and 500 original time points ...
# Starting coherence calc for class--(DOWN1)-- ...
# Loading data for 123 events and 500 original time points ...
# Starting coherence calc for class--(DOWN2)-- ...
# Loading data for 144 events and 500 original time points ...
# Starting coherence calc for class--(FORWARD1)-- ...
# Loading data for 154 events and 500 original time points ...
# Starting coherence calc for class--(FORWARD2)-- ...
# Loading data for 128 events and 500 original time points ...
# Starting coherence calc for class--(GO)-- ...
# Loading data for 40 events and 500 original time points ...
# Starting coherence calc for class--(LEFT1)-- ...
# Loading data for 137 events and 500 original time points ...
# Starting coherence calc for class--(LEFT2)-- ...
# Loading data for 139 events and 500 original time points ...
# Starting coherence calc for class--(RIGHT1)-- ...
# Loading data for 139 events and 500 original time points ...
# Starting coherence calc for class--(RIGHT2)-- ...
# Loading data for 119 events and 500 original time points ...
# Starting coherence calc for class--(UP1)-- ...
# Loading data for 117 events and 500 original time points ...
# Starting coherence calc for class--(UP2)-- ...
# Loading data for 115 events and 500 original time points ...
# Starting coherence calc for subject-7
# Starting coherence calc for class--(BACK1)-- ...
# Loading data for 90 events and 500 original time points ...
# Starting coherence calc for class--(BACK2)-- ...
# Loading data for 108 events and 500 original time points ...
# Starting coherence calc for class--(DOWN1)-- ...
# Loading data for 112 events and 500 original time points ...
# Starting coherence calc for class--(DOWN2)-- ...
# Loading data for 112 events and 500 original time points ...
# Starting coherence calc for class--(FORWARD1)-- ...
# Loading data for 117 events and 500 original time points ...
# Starting coherence calc for class--(FORWARD2)-- ...
# Loading data for 141 events and 500 original time points ...
# Starting coherence calc for class--(GO)-- ...
# Loading data for 40 events and 500 original time points ...
# Starting coherence calc for class--(LEFT1)-- ...
# Loading data for 104 events and 500 original time points ...
# Starting coherence calc for class--(LEFT2)-- ...
# Loading data for 104 events and 500 original time points ...
# Starting coherence calc for class--(RIGHT1)-- ...
# Loading data for 128 events and 500 original time points ...
# Starting coherence calc for class--(RIGHT2)-- ...
# Loading data for 139 events and 500 original time points ...
# Starting coherence calc for class--(UP1)-- ...
# Loading data for 101 events and 500 original time points ...
# Starting coherence calc for class--(UP2)-- ...
# Loading data for 109 events and 500 original time points ...
# Starting coherence calc for subject-8
# Starting coherence calc for class--(BACK1)-- ...
# Loading data for 127 events and 500 original time points ...
# Starting coherence calc for class--(BACK2)-- ...
# Loading data for 79 events and 500 original time points ...
# Starting coherence calc for class--(DOWN1)-- ...
# Loading data for 80 events and 500 original time points ...
# Starting coherence calc for class--(DOWN2)-- ...
# Loading data for 99 events and 500 original time points ...
# Starting coherence calc for class--(FORWARD1)-- ...
# Loading data for 100 events and 500 original time points ...
# Starting coherence calc for class--(FORWARD2)-- ...
# Loading data for 103 events and 500 original time points ...
# Starting coherence calc for class--(GO)-- ...
# Loading data for 40 events and 500 original time points ...
# Starting coherence calc for class--(LEFT1)-- ...
# Loading data for 125 events and 500 original time points ...
# Starting coherence calc for class--(LEFT2)-- ...
# Loading data for 90 events and 500 original time points ...
# Starting coherence calc for class--(RIGHT1)-- ...
# Loading data for 99 events and 500 original time points ...
# Starting coherence calc for class--(RIGHT2)-- ...
# Loading data for 97 events and 500 original time points ...
# Starting coherence calc for class--(UP1)-- ...
# Loading data for 103 events and 500 original time points ...
# Starting coherence calc for class--(UP2)-- ...
# Loading data for 105 events and 500 original time points ...
# Calculation done.

# %%
#np.save('/home/dataFolder/DataPrior/Spanish/coh/coherence_1.npy', allCoh)

# %%
#load coherencies if there is a file
allCoh = np.load('/home/dataFolder/DataPrior/Spanish/coh/coherence.npy',allow_pickle='TRUE').item()

# %%
#let's do some statisctics analysis with it
#should it be subject-dependent or not? As I see we should look for any existing stable crossing with significant coherence across channels, otherwise there is no real sense in what we do.
#Actually that doesnt mean we look for some universal model or phenomenon

# %%
bandsCoh = {
    'Theta': np.where((f >= 4) & (f < 8)),
    'Alpha': np.where((f >= 8) & (f < 13)),
    'Beta_1': np.where((f >= 13) & (f < 19)),
    'Beta_2': np.where((f >= 19) & (f < 30)),
    'Gamma': np.where((f >= 60) & (f < 70))
}
#let's firstly find frequency bands with significant differencies in coherence
#after we find it, we will try to filter the channels by significant diff.
bandCohDiff = {}
for sub in allCoh.keys():
    #we need channel combinations to iterate over it
    uniq_ch = list(combinations(psd[sub].ch_names, 2))
    #reference rest state and word prounaunce condotions
    goCoh = allCoh[sub]['GO']
    wordCoh = np.concatenate([allCoh[sub][x] for x in ['BACK2','DOWN2','FORWARD2','LEFT2','RIGHT2','UP2']])
    #wordCoh = np.concatenate([allCoh[sub][x] for x in ['BACK2']])
    #iterate over pairs
    cur_res = np.zeros((1,wordCoh.shape[2]))
    for pair_name, pair_ind in zip(uniq_ch, range(wordCoh.shape[1])):
        #F, p = f_oneway(goCoh[:,pair_ind,:], wordCoh[:,pair_ind,:], axis = 0)
        F, p = ttest_ind(goCoh[:,pair_ind,:], wordCoh[:,pair_ind,:], axis = 0,equal_var=False)
        cur_res = np.append(cur_res, np.array([p]), axis = 0)
    bandCohDiff[sub] = cur_res[1:,:]

# %%
f, Cxy = signal.coherence(epoData[8]['GO'].get_data()[e,1,:], epoData[8]['GO'].get_data()[e,2,:],fs = 500,nperseg = 125)

# %%
#finding out the indicies of pairs with p-value lower than the threshold
cohD = [np.zeros((bandCohDiff[el].shape[0],bandCohDiff[el].shape[1])) for el in bandCohDiff.keys()]
ps = [np.argwhere(bandCohDiff[i] < 0.001) for i in bandCohDiff.keys()]
for ind, p_arr in enumerate(ps):
    cohD[ind][p_arr] = 1

# %%
sns.heatmap(cohD[0])
# Out:
# <Axes: >

# %%
#I think we got something strange? May be it's some misunderstanding? Why if there are any difference it's spread along all frequencis without exceptions? Strange.
#what if calculate not along frequency axis bur channel pair axis
